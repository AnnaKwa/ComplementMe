# %%
# %matplotlib inline
from IPython.display import clear_output
from importlib import reload

import clothes
reload(clothes)
from clothes import *

# %%
img_file='/home/anna/Downloads/pinterest_images/1c2ff837d5f72dc410fa39700237c9be.jpg'
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# #### Read image

# %%
img0 = cv2.imread(img_file)
plt.imshow(misc.imread(img_file)   )

# %%
img_gcv=load_image_GCV(img_file)
ULvertex, h, w=detect_faces(img_gcv)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-f059e6f6ce25> in <module>()
#       1 img_gcv=load_image_GCV(img_file)
# ----> 2 ULvertex, h, w=detect_faces(img_gcv)
#
# TypeError: 'NoneType' object is not iterable

# %%
rect = patches.Rectangle(ULvertex, w, h, linewidth=1,edgecolor='r',facecolor='none')
fig,ax = plt.subplots(1)
ax.imshow( BGRtoRGB(img0))
ax.add_patch(rect)

# %% [markdown]
# #### Downsample for faster background subtraction and color clustering

# %%
#img_file='images/test_man_img_4.jpg'
bg_subtracted_img0 = bg_subtract(img0, plot=False, flipRGB=True, include_rect=[.05,.05,1.6,1.2])
#rect = patches.Rectangle(ULvertex, w, h, linewidth=2,edgecolor='r',facecolor='none')
fig,ax = plt.subplots(1)
ax.imshow( bg_subtracted_img0)
#ax.add_patch(rect)

# %%
downsampled_img=downsample(bg_subtracted_img0, percent=50, max_length=100)
plt.imshow(downsampled_img)

# %%
xdim, ydim = np.shape(bg_subtracted_img0 )[0], np.shape(bg_subtracted_img0 )[1]
clt = color_clusters(bg_subtracted_img0 , NumColorCenters=5)            # labels_, cluster_centers_, inertia_

grouped_pixels = clt.labels_.reshape(xdim,ydim)
cluster_colors = clt.cluster_centers_

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-fa524d2c24ec> in <module>()
# ----> 1 cluster_colors.format(2)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'format'

# %%
plot_colors(clt)
# Out:
# [ 0.73296579  0.1384619   0.07232772  0.05624459]
# 0.732965792404 [ 157.49765494  124.9866555   102.63009492]
# 0.138461895336 [ 59.10311263  24.02385282  36.20579741]
# 0.0723277248546 [ 197.93753455  183.00221117  173.00055279]
# 0.0562445874057 [ 182.75833789   10.08392564  116.7345544 ]

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-e29311f6f1bf> in <module>()
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
vfunc=np.vectorize(map2color, otypes=[object])
